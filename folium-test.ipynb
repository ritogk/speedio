# %%
import pandas as pd

### Parameters
lat_key = "lat"
lon_key = "lon"

### Read file
df = pd.read_csv("./example.csv", engine="python")

lats = df[lat_key].to_list()
lons = df[lon_key].to_list()

import folium

m = folium.Map(
    location=[35.5, 138.5],
    zoom_start=8,
)

for lat,lon in zip(lats,lons):
    folium.Marker(
        location=[lat,lon],
        popup='Lat: {:.5f} Lon: {:.5f}'.format(lat,lon),
        icon=folium.Icon(color='red')
    ).add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb6d5e991f073e6a014ab2004c5c0d8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb6d5e991f073e6a014ab2004c5c0d8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb6d5e991f073e6a014ab2004c5c0d8e = L.map(
#                 &quot;map_fb6d5e991f073e6a014ab2004c5c0d8e&quot;,
#                 {
#                     center: [35.5, 138.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4aa704cf247f022484abd4923d0873ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fb6d5e991f073e6a014ab2004c5c0d8e);
#
#
#             var marker_ba4619ea1a202d092b9169e3a9049b41 = L.marker(
#                 [35.1070332882127, 138.430800034837],
#                 {}
#             ).addTo(map_fb6d5e991f073e6a014ab2004c5c0d8e);
#
#
#             var icon_0b677dc8001a6545bbfa9244f10f2a9e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba4619ea1a202d092b9169e3a9049b41.setIcon(icon_0b677dc8001a6545bbfa9244f10f2a9e);
#
#
#         var popup_95cd982170398f6f53b81e683d2cdbbd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b38bdd0034e5d59c502b3298c7fe98e6 = $(`&lt;div id=&quot;html_b38bdd0034e5d59c502b3298c7fe98e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lat: 35.10703 Lon: 138.43080&lt;/div&gt;`)[0];
#                 popup_95cd982170398f6f53b81e683d2cdbbd.setContent(html_b38bdd0034e5d59c502b3298c7fe98e6);
#
#
#
#         marker_ba4619ea1a202d092b9169e3a9049b41.bindPopup(popup_95cd982170398f6f53b81e683d2cdbbd)
#         ;
#
#
#
#
#             var marker_91a599e3f0a64583246e81d97119c5fc = L.marker(
#                 [35.30929230545, 138.032782665447],
#                 {}
#             ).addTo(map_fb6d5e991f073e6a014ab2004c5c0d8e);
#
#
#             var icon_99544f2321490b360211c9c1a91eda3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_91a599e3f0a64583246e81d97119c5fc.setIcon(icon_99544f2321490b360211c9c1a91eda3a);
#
#
#         var popup_d235a3f63cdc68b00cf6c815b9fc9d64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_11708e0fb4bedb30814c0a53513a02bd = $(`&lt;div id=&quot;html_11708e0fb4bedb30814c0a53513a02bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lat: 35.30929 Lon: 138.03278&lt;/div&gt;`)[0];
#                 popup_d235a3f63cdc68b00cf6c815b9fc9d64.setContent(html_11708e0fb4bedb30814c0a53513a02bd);
#
#
#
#         marker_91a599e3f0a64583246e81d97119c5fc.bindPopup(popup_d235a3f63cdc68b00cf6c815b9fc9d64)
#         ;
#
#
#
#
#             var marker_a066e989527d618f7b73da2111e5876d = L.marker(
#                 [35.5129782238533, 138.144615674402],
#                 {}
#             ).addTo(map_fb6d5e991f073e6a014ab2004c5c0d8e);
#
#
#             var icon_ac1cad7986cc659893a3ad7663ae7a52 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a066e989527d618f7b73da2111e5876d.setIcon(icon_ac1cad7986cc659893a3ad7663ae7a52);
#
#
#         var popup_38d5b8165babf38e8895fe565ed275b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ee5d8e56b96b160c7ae5f939a8bf46e = $(`&lt;div id=&quot;html_1ee5d8e56b96b160c7ae5f939a8bf46e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lat: 35.51298 Lon: 138.14462&lt;/div&gt;`)[0];
#                 popup_38d5b8165babf38e8895fe565ed275b0.setContent(html_1ee5d8e56b96b160c7ae5f939a8bf46e);
#
#
#
#         marker_a066e989527d618f7b73da2111e5876d.bindPopup(popup_38d5b8165babf38e8895fe565ed275b0)
#         ;
#
#
#
#
#             var marker_40230b51e70cf259a32c685dc2ccca0a = L.marker(
#                 [35.5493244016185, 138.834350811069],
#                 {}
#             ).addTo(map_fb6d5e991f073e6a014ab2004c5c0d8e);
#
#
#             var icon_d3bba47407fb4f39a59758ba41c5fc27 = L.AwesomeMarkers.icon(
